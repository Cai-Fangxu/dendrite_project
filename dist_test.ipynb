# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
seed = 42
np.random.seed(seed)
n_samples = 20000
ns = 200
b = 2.0

us = np.random.normal(0, 1, (n_samples, ns))
zs = ((us-b)>0)*(us-b)
zs2 = np.sort(zs, axis=-1)[:, :-2]
currents = np.sum(zs, axis=-1)
currents2 = np.sum(zs2, axis=-1)

# %%
tmpList = np.genfromtxt("tmp_data/tmpList.csv", delimiter=',')

# %%
plt.hist(currents, bins=40, range=(0.0000, np.max(currents)), histtype="step", density=True);
# plt.hist(currents2, bins=40, range=(0.00001, np.max(currents)), histtype="step");
plt.plot(tmpList[:, 0], tmpList[:, 1])
# plt.ylim(0, 0.45)
# plt.xlim(0, 2)
